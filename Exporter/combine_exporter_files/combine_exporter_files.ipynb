# %%
import pandas as pd
from pathlib import Path

# %%
exporter_path = Path(r"\\psc-data\E\Applications\Starfish\Files\exporter")
output_path = Path(r"\\psc-data\E\Data\exporter_data")

# %%
files = exporter_path.glob("*.csv")

file_types = set()
for f in files:
    ft = f.stem.split("-")[0]
    file_types.add(ft)
    print(f.stem.split("-"))
print(file_types)
# Out:
# ['appointments', '09182018020601821']
# ['appointments', '09192018020601540']
# ['attendance', '09172018020600000']
# ['attendance', '09182018020601821']
# ['attendance', '09192018']
# ['attendance', '09192018020601540']
# ['intake_forms', '09182018020601821']
# ['intake_forms', '09192018020601540']
# ['meeting_speednotes', '09182018020601821']
# ['meeting_speednotes', '09192018020601540']
# ['notes', '09182018020601821']
# ['notes', '09192018020601540']
# ['student_academic_plan_overview', '09182018020601821']
# ['student_academic_plan_overview', '09192018020601540']
# ['student_academic_plan_requirements', '09182018020601821']
# ['student_academic_plan_requirements', '09192018020601540']
# ['success_plan_overview', '09182018020601821']
# ['success_plan_overview', '09192018020601540']
# ['tracking', '09182018020601821']
# ['tracking', '09192018020601540']
# {'student_academic_plan_overview', 'intake_forms', 'tracking', 'notes', 'student_academic_plan_requirements', 'success_plan_overview', 'attendance', 'meeting_speednotes', 'appointments'}

# %%
for ft in file_types:
    if ft == "attendance":
        files = exporter_path.glob(ft + "*.csv")
        combined_df = pd.concat([pd.read_csv(f) for f in files])
        print(ft, combined_df.shape)
        # print(combined_df.columns)
        print(combined_df.info())
        combined_df = combined_df.drop_duplicates()
        print(ft, combined_df.shape)

        outfile = output_path / (ft + ".csv")
        print(outfile)
        combined_df.to_csv(outfile, index=False)
# Out:
# attendance (5936, 9)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5936 entries, 0 to 307
# Data columns (total 9 columns):
# course_section_name            5936 non-null object
# course_section_id              5936 non-null object
# student_first_name             5936 non-null object
# student_last_name              5936 non-null object
# student_userid                 5936 non-null object
# student_integration_id         5936 non-null object
# student_institutional_email    5936 non-null object
# attend_status                  5936 non-null object
# attend_date                    5936 non-null object
# dtypes: object(9)
# memory usage: 463.8+ KB
# None
# attendance (5912, 9)
# \\psc-data\E\Data\exporter_data\attendance.csv

# %%
"""
Combines daily difference files from Starfish Exporter into one file.
"""
import pandas as pd
from pathlib import Path

exporter_path = Path(r"\\psc-data\E\Applications\Starfish\Files\exporter")
output_path = Path(r"\\psc-data\E\Data\exporter_data")

files = exporter_path.glob("*.csv")

file_types = set()
for f in files:
    ft = f.stem.split("-")[0]
    file_types.add(ft)

for ft in file_types:
    files = exporter_path.glob(ft + "*.csv")
    combined_df = pd.concat([pd.read_csv(f) for f in files])
    combined_df = combined_df.drop_duplicates()

    outfile = output_path / (ft + ".csv")
    combined_df.to_csv(outfile, index=False)
